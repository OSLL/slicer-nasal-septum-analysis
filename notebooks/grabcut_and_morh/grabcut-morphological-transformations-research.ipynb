# %%
DATASET_NAME = "{DATASET_NAME}"

import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_110.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Naive grabcut

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_110.png')
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (20, 20, 300, 300)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f3006a80790>,
# ...
#  None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_123.png')
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (20, 20, 300, 300)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f3006b418a0>,
# ...
#  None)

# %% [markdown]
# ### Experiments with grabCut region

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_139.png')
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (100, 100, 200, 250)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f3005009bd0>,
# ...
#  None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_139.png')
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_163.png')
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_163.png')
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (25, 25, 300, 200)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f30050da920>,
# ...
#  None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_176.png')
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_176.png')
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (100, 50, 100, 100)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f300469b940>,
# ...
#  None)

# %% [markdown]
# Ooops. It is possible for grabcut to find no cut!

# %% [markdown]
# ### Split image on "black" and "white" components

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Read image
img = cv2.imread(f'/kaggle/input/{DATASET_NAME}/slice_176.png')
hh, ww = img.shape[:2]

# threshold on white
# Define lower and uppper limits
lower = np.array([150, 150, 150])
upper = np.array([255, 255, 255])

# Create mask to only select black
thresh = cv2.inRange(img, lower, upper)

# apply morphology
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (20,20))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# invert morp image
mask = 255 - morph

# apply mask to image
result = cv2.bitwise_and(img, img, mask=mask)


# save results
# cv2.imwrite('pills_thresh.jpg', thresh)
# cv2.imwrite('pills_morph.jpg', morph)
# cv2.imwrite('pills_mask.jpg', mask)
# cv2.imwrite('pills_result.jpg', result)

# cv2.imshow('thresh', thresh)
# cv2.imshow('morph', morph)
# cv2.imshow('mask', mask)
# cv2.imshow('result', result)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

plt.imshow(thresh),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f2ff781ded0>,
# ...
#  None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_176.png')
assert img is not None, "file could not be read, check with os.path.exists()"
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (150,100,150,250)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# newmask is the mask image I manually labelled
newmask = mask
# wherever it is marked white (sure foreground), change mask=1
# wherever it is marked black (sure background), change mask=0
mask[newmask == 0] = 0
mask[newmask == 255] = 1
mask, bgdModel, fgdModel = cv.grabCut(img,mask,None,bgdModel,fgdModel,5,cv.GC_INIT_WITH_MASK)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f2ff7b147f0>,
# ...
#  None)

# %% [markdown]
# Пазухи выделились хорошо, за исключением лишней перегородки между ними.

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_176.png')
assert img is not None, "file could not be read, check with os.path.exists()"
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (100,50,150,250)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# newmask is the mask image I manually labelled
newmask = mask
# wherever it is marked white (sure foreground), change mask=1
# wherever it is marked black (sure background), change mask=0
mask[newmask == 0] = 0
mask[newmask == 255] = 1
mask, bgdModel, fgdModel = cv.grabCut(img,mask,None,bgdModel,fgdModel,5,cv.GC_INIT_WITH_MASK)
mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask[:,:,np.newaxis]
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f30050ed4b0>,
# ...
#  None)

# %% [markdown]
# Как видим, пазухи выделились отлично, за исключением лишних костей.

# %% [markdown]
# ### Morphological Transformations Research

# %% [markdown]
# Ставим целью с помощью морфологических преобразований достроить тонкие стенки в пазухах.

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
plt.imshow(img)
plt.show()

# %% [markdown]
# ### MORPH_GRADIENT

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = np.ones((3,3),np.uint8)
img = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### MORPH_CLOSE

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = np.ones((5,5),np.uint8)
img = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### MORPH_OPEN

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = np.ones((5,5),np.uint8)
img = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Erode transform

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = np.ones((5,5),np.uint8)
img = cv.erode(img,kernel,iterations = 1)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Dilate transform

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = np.ones((5,5),np.uint8)
img = cv.dilate(img,kernel,iterations = 1)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### morphologyEx

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = np.ones((32,32),np.uint8)
# kernel = np.identity(20, np.uint8)
img = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = np.ones((2,2),np.uint8)
img = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(5,5))
# kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
# kernel = cv.getStructuringElement(cv.MORPH_RECT,(5,5))
img = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(f'/kaggle/input/{DATASET_NAME}/slice_185.png')[50:150, 250:350,]
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(32,32))
# kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
# kernel = cv.getStructuringElement(cv.MORPH_RECT,(5,5))
img = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
plt.imshow(img)
plt.show()

# %% [markdown]
# Вывод: результаты сомнительные. Лучше всего себя показали MORPH_GRADIENT и MORPH_TOPHAT.
